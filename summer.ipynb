# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Assignment_summer_Olympics/summer.csv")
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %%
df.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
data =df.dropna()
data.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       0
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %% [markdown]
# # Summer Olympics Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
listofcities = data['City'].unique()
Cities=list(listofcities)
pd.DataFrame(Cities,columns=['City'])
# Out:
#                      City
# 0                  Athens
# 1                   Paris
# 2                St Louis
# 3                  London
# 4               Stockholm
# 5                 Antwerp
# 6               Amsterdam
# 7             Los Angeles
# 8                  Berlin
# 9                Helsinki
# 10  Melbourne / Stockholm
# 11                   Rome
# 12                  Tokyo
# 13                 Mexico
# 14                 Munich
# 15               Montreal
# 16                 Moscow
# 17                  Seoul
# 18              Barcelona
# 19                Atlanta
# 20                 Sydney
# 21                Beijing

# %%
type(listofcities)
# Out:
# numpy.ndarray

# %%
listofrecord=[]
for City in data['City'].unique():
    #print(data['City'])
    listofrecord.append([City ,len(data[data['City'] == City])])
pd.DataFrame(listofrecord ,columns=['City','Count'])
# Out:
#                      City  Count
# 0                  Athens   2149
# 1                   Paris   1396
# 2                St Louis    470
# 3                  London   3563
# 4               Stockholm    885
# 5                 Antwerp   1298
# 6               Amsterdam    710
# 7             Los Angeles   2074
# 8                  Berlin    875
# 9                Helsinki    889
# 10  Melbourne / Stockholm    885
# 11                   Rome    882
# 12                  Tokyo   1010
# 13                 Mexico   1031
# 14                 Munich   1185
# 15               Montreal   1305
# 16                 Moscow   1387
# 17                  Seoul   1546
# 18              Barcelona   1705
# 19                Atlanta   1859
# 20                 Sydney   2015
# 21                Beijing   2042

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
Goldlist=data[data['Medal']=='Gold']
Goldlist.head()
# Out:
#     Year    City      Sport  ... Gender                       Event Medal
# 0   1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3   1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6   1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9   1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13  1896  Athens  Athletics  ...    Men                        100M  Gold
#
# [5 rows x 9 columns]

# %%
Goldlist['Sport'].unique()
listofgold=[]
for Sport in Goldlist['Sport'].unique():
    listofgold.append([Sport, len(Goldlist[Goldlist['Sport'] == Sport])])
listofgold
# Out:
# [['Aquatics', 1421],
#  ['Athletics', 1214],
#  ['Cycling', 371],
#  ['Fencing', 552],
#  ['Gymnastics', 820],
#  ['Shooting', 384],
#  ['Tennis', 92],
#  ['Weightlifting', 199],
#  ['Wrestling', 391],
#  ['Archery', 126],
#  ['Basque Pelota', 2],
#  ['Cricket', 12],
#  ['Croquet', 4],
#  ['Equestrian', 320],
#  ['Football', 503],
#  ['Golf', 13],
#  ['Polo', 22],
#  ['Rowing', 890],
#  ['Rugby', 78],
#  ['Sailing', 412],
#  ['Tug of War', 36],
#  ['Boxing', 239],
#  ['Lacrosse', 28],
#  ['Roque', 1],
#  ['Hockey', 486],
#  ['Jeu de paume', 1],
#  ['Rackets', 3],
#  ['Skating', 9],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 60],
#  ['Ice Hockey', 8],
#  ['Basketball', 342],
#  ['Canoe / Kayak', 334],
#  ['Handball', 321],
#  ['Judo', 123],
#  ['Volleyball', 332],
#  ['Table Tennis', 46],
#  ['Badminton', 46],
#  ['Baseball', 111],
#  ['Softball', 60],
#  ['Taekwondo', 32],
#  ['Triathlon', 8],
#  ['Canoe', 27]]

# %%
pd.DataFrame(listofgold,columns = ['Sport','GoldMedal']).sort_values(by='GoldMedal', ascending=False).head().plot(x = 'Sport', y = 'GoldMedal', kind = 'bar', figsize = (15,5))

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
Sportarr=[]
for Sport in data['Sport'].unique():
    Sportarr.append([Sport,len(data[data['Sport']== Sport])])
pd.DataFrame(Sportarr,columns = ['Sport','Medal']).sort_values(by='Medal', ascending=False).head().plot(x = 'Sport', y = 'Medal', kind = 'bar', figsize = (15,10))

# %%
Sportarr
# Out:
# [['Aquatics', 4170],
#  ['Athletics', 3637],
#  ['Cycling', 1105],
#  ['Fencing', 1613],
#  ['Gymnastics', 2307],
#  ['Shooting', 1150],
#  ['Tennis', 296],
#  ['Weightlifting', 591],
#  ['Wrestling', 1211],
#  ['Archery', 329],
#  ['Basque Pelota', 4],
#  ['Cricket', 24],
#  ['Croquet', 8],
#  ['Equestrian', 939],
#  ['Football', 1497],
#  ['Golf', 30],
#  ['Polo', 66],
#  ['Rowing', 2667],
#  ['Rugby', 192],
#  ['Sailing', 1109],
#  ['Tug of War', 94],
#  ['Boxing', 894],
#  ['Lacrosse', 59],
#  ['Roque', 3],
#  ['Hockey', 1422],
#  ['Jeu de paume', 3],
#  ['Rackets', 10],
#  ['Skating', 27],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 180],
#  ['Ice Hockey', 27],
#  ['Basketball', 1012],
#  ['Canoe / Kayak', 1002],
#  ['Handball', 973],
#  ['Judo', 491],
#  ['Volleyball', 994],
#  ['Table Tennis', 144],
#  ['Badminton', 144],
#  ['Baseball', 335],
#  ['Softball', 180],
#  ['Taekwondo', 112],
#  ['Triathlon', 24],
#  ['Canoe', 81]]

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
data.head()
# Out:
#    Year    City     Sport  ... Gender                       Event   Medal
# 0  1896  Athens  Aquatics  ...    Men              100M Freestyle    Gold
# 1  1896  Athens  Aquatics  ...    Men              100M Freestyle  Silver
# 2  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Silver
#
# [5 rows x 9 columns]

# %%
playername=[]
for Athlete in data['Athlete'].unique():
    playername.append([Athlete,len(data[data['Athlete']==Athlete])])
pd.DataFrame(playername,columns = ['Athlete','freq']).sort_values(by='freq', ascending=False).head().plot(x = 'Athlete', y = 'freq', kind = 'bar', figsize = (15,5))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
Goldlist=data[data['Medal']=='Gold']
Goldlist.head()
# Out:
#     Year    City      Sport  ... Gender                       Event Medal
# 0   1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3   1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6   1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9   1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13  1896  Athens  Athletics  ...    Men                        100M  Gold
#
# [5 rows x 9 columns]

# %%
goldplayer=[]
for Athlete in Goldlist['Athlete'].unique():
    goldplayer.append([Athlete,len(Goldlist[Goldlist['Athlete']==Athlete])])
pd.DataFrame(goldplayer, columns=['Athlete','Medal']).sort_values(by='Medal',ascending=False).head().plot(x='Athlete',y='Medal',kind='bar',figsize=(15,10))

# %%
goldplayer
# Out:
# [['HAJOS, Alfred', 2],
#  ['MALOKINIS, Ioannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['BURKE, Thomas', 2],
#  ['CURTIS, Thomas', 1],
#  ['FLACK, Edwin', 2],
#  ['GARRETT, Robert', 2],
#  ['CLARK, Ellery', 2],
#  ['LOUIS, Spyridon', 1],
#  ['HOYT, William Welles', 1],
#  ['CONNOLLY, James', 1],
#  ['KONSTANTINIDIS, Aristidis', 1],
#  ['FLAMENG, Léon', 1],
#  ['MASSON, Paul', 3],
#  ['SCHMAL, Adolf', 1],
#  ['GRAVELOTTE, Eugène-Henri', 1],
#  ['PYRGOS, Leonidas', 1],
#  ['GEORGIADIS, Ioannis', 1],
#  ['WEINGÄRTNER, Hermann', 3],
#  ['FLATOW, Alfred', 3],
#  ['ZUTTER, Louis', 1],
#  ['MITROPOULOS, Ioannis', 1],
#  ['ANDRIAKOPOULOS, Nicolaos', 1],
#  ['BÖCKER, Konrad', 2],
#  ['FLATOW, Gustav Felix', 2],
#  ['HILMAR, Georg', 2],
#  ['HOFMANN, Fritz', 2],
#  ['MANTEUFFEL, Fritz', 2],
#  ['NEUKIRCH, Karl', 2],
#  ['RÖSTEL, Richard', 2],
#  ['SCHUFT, Gustav', 2],
#  ['SCHUMANN, Carl', 4],
#  ['PAINE, John', 1],
#  ['PHRANGOUDIS, Joannis', 1],
#  ['PAINE, Sumner', 1],
# ...

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
Goldlist[Goldlist['Country']=='IND'].sort_values(by='Year',ascending= True).head(20)
# Out:
#       Year         City   Sport Discipline  ... Country Gender   Event Medal
# 5512  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5526  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5525  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5524  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5523  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5522  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5520  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5521  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5518  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5517  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# 5516  1928    Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
# ...

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
Eventlist=[]
for Event in data['Event'].unique():
    Eventlist.append([Event,len(data[data['Event']== Event])])
pd.DataFrame(Eventlist,columns = ['Event','freq']).sort_values(by='freq', ascending=False).head().plot(x = 'Event', y = 'freq', kind = 'bar', figsize = (15,10))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
Femalelist= data[data['Gender']== 'Women']
GoldFem= Femalelist[Femalelist['Medal']=='Gold']
GoldFem
# Out:
#        Year      City  ...                                    Event Medal
# 417    1900     Paris  ...                               Individual  Gold
# 641    1900     Paris  ...                            Mixed Doubles  Gold
# 649    1900     Paris  ...                                  Singles  Gold
# 710    1904  St Louis  ...  Double Columbia Round (50Y - 40Y - 30Y)  Gold
# 713    1904  St Louis  ...        Double National Round (60Y - 50Y)  Gold
# ...     ...       ...  ...                                      ...   ...
# 31081  2012    London  ...                                     75KG  Gold
# 31097  2012    London  ...                                 Wf 48 KG  Gold
# 31105  2012    London  ...                                 Wf 55 KG  Gold
# 31113  2012    London  ...                                 Wf 63 KG  Gold
# 31121  2012    London  ...                                 Wf 72 KG  Gold
#
# [2786 rows x 9 columns]

# %%
femlist=[]
for Sport in GoldFem['Sport'].unique():
    femlist.append([Sport,len(GoldFem[GoldFem['Sport']== Sport])])
pd.DataFrame(femlist,columns=['Sport','Medal']).sort_values(by='Sport',ascending=False).head().plot(x ='Sport', y='Medal',kind='bar',figsize=(15,10))
